# %%
import pandas as pd
import matplotlib.pyplot as plt #导入matplotlib.pyplot库用于绘图
import collections #导入collections库用于定性变量取值计数

#数据预处理
#raw_data = pd.read_csv('Adult.csv',na_values=' ?') #设定' ?'为缺失值
raw_data = pd.read_csv('adult.data',na_values=' ?') #设定' ?'为缺失值
fill_na = lambda col:col.fillna(col.mode()[0]) #定义 fill_na 函数，用众数填充缺 失值
data = raw_data.apply(fill_na, axis = 0)  #将填充后的数据赋给data

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#绘制饼图
from collections import Counter
items = data['sex'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典
print(count) #输出计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common())

#设置饼图百分比
sizes = list(countSort.values())
for i in range(len(sizes)):
    sizes[i] = round(sizes[i]/32561 * 100,2)
labels = list(countSort.keys()) #设置饼图标签 
plt.pie(sizes,labels=labels,autopct='%.2f%%',counterclock=True,
        startangle= 90,radius=2)
plt.show()
# Out:
# Counter({' Male': 21790, ' Female': 10771})

# %%
#绘制饼图
from collections import Counter
items = data['workclass'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典
print(count) #输出计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common())

#设置饼图百分比
sizes = list(countSort.values())
for i in range(len(sizes)):
    sizes[i] = round(sizes[i]/32561 * 100,2)
labels = list(countSort.keys()) #设置饼图标签 
plt.pie(sizes,labels=labels,autopct='%.2f%%',radius=2.0,
        counterclock=False,startangle= 20) #绘制饼图
plt.show()
# Out:
# Counter({' Private': 24532, ' Self-emp-not-inc': 2541, ' Local-gov': 2093, ' State-gov': 1298, ' Self-emp-inc': 1116, ' Federal-gov': 960, ' Without-pay': 14, ' Never-worked': 7})

# %%
#绘制饼图
from collections import Counter
items = data['race'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典
print(count) #输出计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common())

#设置饼图百分比
sizes = list(countSort.values())
for i in range(len(sizes)):
    sizes[i] = round(sizes[i]/32561 * 100,2)
labels = list(countSort.keys()) #设置饼图标签 
plt.pie(sizes,labels=labels,autopct='%.2f%%',radius=2.0,
        counterclock=False,startangle= 190) #绘制饼图
plt.show()
# Out:
# Counter({' White': 27816, ' Black': 3124, ' Asian-Pac-Islander': 1039, ' Amer-Indian-Eskimo': 311, ' Other': 271})

# %%
#绘制饼图
from collections import Counter
items = data['race'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典


sizes = list(count.values())
for i in range(len(sizes)):   
    sizes[i] = round(sizes[i]/32561 * 100,2)   #设置饼图百分比
labels = list(count.keys())     #设置饼图标签 
plt.pie(sizes,labels=labels,    #绘制饼图
        autopct='%.2f%%',       #数值保留固定小数位
        radius=2.5,             #饼图大小
        startangle= 180,        #逆时针起始角度设置
        counterclock=True,      #是否让饼图按逆时针顺序呈现
        pctdistance = 0.75)     #数值距圆心半径倍数距离
plt.show()

# %%
#绘制饼图
from collections import Counter
items = data['workclass'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典


sizes = list(count.values())
for i in range(len(sizes)):   
    sizes[i] = round(sizes[i]/32561 * 100,2)   #设置饼图百分比
labels = list(count.keys())     #设置饼图标签 
plt.pie(sizes,labels=labels,    #绘制饼图
        autopct='%.2f%%',       #数值保留固定小数位
        radius=2.5,             #饼图大小
        startangle= 180,        #逆时针起始角度设置
        counterclock=False,      #是否让饼图按逆时针顺序呈现
        pctdistance = 0.75)     #数值距圆心半径倍数距离
plt.show()

# %%
#绘制饼图
from collections import Counter
items = data['relationship'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典
print(count) #输出计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common())

#设置饼图百分比
sizes = list(countSort.values())
for i in range(len(sizes)):
    sizes[i] = round(sizes[i]/32561 * 100,2)
labels = list(countSort.keys()) #设置饼图标签 
plt.pie(sizes,labels=labels,autopct='%.2f%%',radius=2.0,
        counterclock=False,startangle= 20) #绘制饼图
plt.show()
# Out:
# Counter({' Husband': 13193, ' Not-in-family': 8305, ' Own-child': 5068, ' Unmarried': 3446, ' Wife': 1568, ' Other-relative': 981})

# %%
#绘制饼图
from collections import Counter
items = data['workclass'] #提取需绘制饼图的数据列
count = Counter(items) #返回该列取值的计数字典
print(count) #输出计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common())

#设置饼图百分比
sizes = list(countSort.values())
for i in range(len(sizes)):
    sizes[i] = round(sizes[i]/32561 * 100,2)
labels = list(countSort.keys()) #设置饼图标签 
plt.pie(sizes,labels=labels,autopct='%.2f%%',radius=2.0,
        counterclock=False,startangle= 20) #绘制饼图
plt.show()
# Out:
# Counter({' Private': 24532, ' Self-emp-not-inc': 2541, ' Local-gov': 2093, ' State-gov': 1298, ' Self-emp-inc': 1116, ' Federal-gov': 960, ' Without-pay': 14, ' Never-worked': 7})

# %%
#绘制条形图
items = data['education'] #提取需绘制直方图的数据列
count = Counter(items)     #返回该列取值的计数字典
countSort = collections.OrderedDict()
countSort = dict(count.most_common()) 
print(countSort)

plt.figure(figsize=(10,5))  #设置输出图片大小
plt.bar(countSort.keys(),countSort.values()) #绘制条形图 
plt.xlabel('education') #设置横轴标签 
plt.xticks(rotation=45)     #x轴标签文字旋转45度角
plt.ylabel('account')       #设置纵轴标签
plt.show()
# Out:
# {' HS-grad': 10501, ' Some-college': 7291, ' Bachelors': 5355, ' Masters': 1723, ' Assoc-voc': 1382, ' 11th': 1175, ' Assoc-acdm': 1067, ' 10th': 933, ' 7th-8th': 646, ' Prof-school': 576, ' 9th': 514, ' 12th': 433, ' Doctorate': 413, ' 5th-6th': 333, ' 1st-4th': 168, ' Preschool': 51}

# %%
items = data['capital-loss'] #提取需分析统计量的数据列 
items.describe()
# Out:
# count    32561.000000
# mean        87.303830
# std        402.960219
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital-loss, dtype: float64

# %%
#绘制每周工作小时数分布条形图
from collections import Counter
items = data['hours-per-week']   #提取需绘制直方图的数据列
count = Counter(items)   #返回该列取值的计数字典

countSort = collections.OrderedDict()
countSort = dict(count.most_common())

plt.figure(figsize=(10,5))  #设置输出图片大小
plt.bar(countSort.keys(),countSort.values())
plt.xlabel('hours-per-week')
plt.ylabel('account')

plt.show()

# %%
items.describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
items = data['native-country']
count = Counter(items)      #返回该列取值的计数字典

country = collections.OrderedDict()
country = dict(count.most_common())

# %%
del country[' United-States']  #删除字典中的指定key键

# %%
x = list(country.keys())     #提取国家列
y = list(country.values())   #提取计数列
x.reverse()                  #将列表按升序排列
y.reverse()
plt.figure(figsize=(10,10))    #设置画布的尺寸
plt.barh(x,y)                  #绘制水平条形图
plt.ylabel('native-country')   #设置y轴标签
plt.xlabel('account')          #设置x轴标签
plt.show()
